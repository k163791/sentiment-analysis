# %%
# importing all necessary libraries to run the code
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk import NaiveBayesClassifier
from sklearn.model_selection import train_test_split
from nltk.stem import PorterStemmer
import re
# using the variable sw to hold all stopwords that are in English
sw = stopwords.words('english')

# %%
ds = pd.read_csv('/home/uzair/Documents/Semester 6/Projects/Data Science/Sentiment/googleplaystore_user_reviews.csv/googleplaystore_user_reviews.csv')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
# App                       64295 non-null object
# Translated_Review         37427 non-null object
# Sentiment                 37432 non-null object
# Sentiment_Polarity        37432 non-null float64
# Sentiment_Subjectivity    37432 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
# Number of elements before removing the NaN values
print('Size before removing Nan: %s'% len(ds))

# Number of elements after removing the NaN values
ds.dropna(axis=0, inplace=True)
print('Size after removing Nan: %s'% len(ds))
# Out:
# Size before removing Nan: 64295
# Size after removing Nan: 37427

# %%
def cleaning_data(data):
    aux_list = []
    flag = False
    for phase_word in data:
        word_list = []
        for word in phase_word.split():
            word = word.lower()
            if flag and not word in sw:
                flag = False
                word_list.append('not_'+word)
                continue
            if re.search('(n\'t)$|(not)|(no)|(never)', word):
                flag = True
                continue
            if not word in sw:
                word = re.sub('[\W_0-9]', ' ', word)
                word_list.append(word)
        aux_list.append(' '.join(word_list))
    return aux_list

# %%
X = cleaning_data(ds['Translated_Review'])
y = ds['Sentiment']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB(alpha = 10)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
vectorizer.fit(X)
X_train = vectorizer.transform(X_train)
X_test = vectorizer.transform(X_test)
# j = []
# h = cleaning_data(j)
# h = vectorizer.transform(h)

# %%
nb.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=10, class_prior=None, fit_prior=True)

# %%
from sklearn.model_selection import cross_val_score  # import cross_val_score from sklear.model_selection
accuracies = cross_val_score(estimator = nb, X = X_train, y = y_train, cv = 10) # do K- fold cross validation on our traing data and its sentimenst with 10 fold cross validation
accuracies.mean() # measure the mean accuray of 10 fold cross validation
# Out:
# 0.6721889045429685

# %%
y_pred_nb = nb.predict(X_test)

# %%
from sklearn import metrics # import metrics from sklearn
metrics.accuracy_score(y_test, y_pred_nb)
# Out:
# 0.673657493988779

# %%
from sklearn.linear_model import LogisticRegression # import Logistic Regression model from sklearn.linear_model
logisticRegr = LogisticRegression(C = 1.1)

# %%
logisticRegr.fit(X_train, y_train)
from sklearn.model_selection import cross_val_score # import cross_val_score from sklear.model_selection
accuracies = cross_val_score(estimator = logisticRegr, X = X_train, y = y_train, cv = 10) # do K- fold cross validation on our traing data and its sentimenst with 10 fold cross validation
accuracies.mean()
# Out:
# /home/uzair/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/uzair/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/uzair/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/uzair/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.9222804676988391

# %%
y_pred_lg = logisticRegr.predict(X_test)
print(y_pred_lg)
# Out:
# ['Positive' 'Positive' 'Positive' ... 'Positive' 'Positive' 'Positive']

# %%
from sklearn import metrics # import metrics from sklearn
metrics.accuracy_score(y_test, y_pred_lg)
# Out:
# 0.9270638525247128

# %%
df = pd.DataFrame(y_pred_lg)

# %%
df.to_csv('/home/uzair/Documents/Semester 6/Projects/Data Science/Sentiment/googleplaystore_user_reviews.csv/Outputs.csv')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
dl = pd.DataFrame(X_test)
dl
# Out:
#                                                       0
# 0       styles challenging time consuming end come nice
# 1     works perfectly im impressed work guys keep ei...
# 2     crazy first try bam it  chose ones even people...
# 3     graphics ok  manual acceleration  good  anyway...
# 4     creating account always showing error occurred
# 5                             good learning words fast
# 6                first time feel exhausted  good job
# 7                                         training plan
# 8     gameplay graphics entertaining  game loaded vi...
# 9     server  china beijing  finally fixed  however ...
# 10    i ve learned lot letting show little not_easy ...
# 11    worst servers iran    first time tried game ac...
# 12    free version used reliable last two updates pr...
# 13    fact not_choose currency want not_payment fees...
# 14    many vip player  extra effect top up alot more...
# 15    good free app  first like hell not_played bit ...
# 16    great way kill time  great get past level stuc...
# 17    great fun game  need spend money good it  need...
# 18    putting password disaster half  cant change av...
# 19                          looks good change language
# 20    rubbish update  not_even backup apk like befor...
# 21    order advance really able enjoy game spend ser...
# 22    love game  fast paced zone moves quickly reall...
# 23    phone nexus  p latest update sucks model game ...
# 24                                                 nice
# 25                     not_poor texting person like me
# 26    one favourite games addictive  would ve nice a...
# 27    not_fun play top option record screen  always ...
# 28    used games  easy learn  fun perfect hard maste...
# 29    simply gorgeous  love game        what  anythi...
# ...                                                 ...
# 7456  good game  one small thing daily quest written...
# 7457                                 thank fast booking
# 7458  improved search engine site s active facilitat...
# 7459  not_entirely impressed brought text book uni c...
# 7460    star latest update  open without crashing  i...
# 7461  far good     i ve using   week pretty cool  wo...
# 7462         shows keep starting right middle watching
# 7463  big issue not_delete pdf  using mobile version...
# 7464                                               best
# 7465                basic powerful gets straight point
# 7466  updated app  even get private chat always get ...
# 7467                                              well
# 7468  not_happy app  i ve using year lately cant sea...
# 7469  like it  works great able keep track appointme...
# 7470  disappointed several occasions i ve tried acti...
# 7471  good pictures work blogging   years definitely...
# 7472  playing shooting games game greater love game ...
# 7473  absolute rubbish     fake google  fake reviews...
# 7474  hi  would like not_remove vignette effect ever...
# 7475  great wife  wife enjoy much  kinda person like...
# 7476  best game ever played great job add build free...
# 7477  wow helpful  think everyone it  cos helps u no...
# 7478               not_receive email  not_reply message
# 7479  simply amazing  data backed up  contacts  cale...
# 7480  got smart watch preloaded it  works fine  simp...
# 7481  used   years  every course played across usa  ...
# 7482  today not_file manager not_delete write sd car...
# 7483                                               west
# 7484                                        seems great
# 7485  exactly described  please bring live fuel pric...
#
# [7486 rows x 1 columns]

# %%
dz = pd.DataFrame(X_test,y_pred_lg)

# %%
dz
dz.to_csv('/home/uzair/Documents/Semester 6/Projects/Data Science/Sentiment/googleplaystore_user_reviews.csv/Predictions.csv')

# %%
dz
# Out:
#                                                           0
# Positive                                  not_user-friendly
# Positive  love app  mother lives georgia inlaws ohio hel...
# Positive                                               cool
# Positive                                         nice app
# Positive  two stars desktop version long overdue devs se...
# Negative  i ve using week not_already disciplined workin...
# Positive  used old format new format threw bit drive thr...
# Positive  great time killer   relaxing  things would cha...
# Positive  addition austin bucks  deleting app  liked mic...
# Positive                           makes saving   breeze
# Positive  really good problem ads watching   irritates l...
# Positive  long time user online platform  admit download...
# Positive  great addictive game  playing year not_things ...
# Positive  used enjoy game  lately able win single match ...
# Positive  really really like app  i m disappointed  even...
# Neutral   game buggy  frustrating  constantly crashing  ...
# Positive  used paid version years satisfied except searc...
# Positive  great app  show rain     graph show rain      ...
# Positive  big problem itoken  often travel england afrai...
# Positive                                              great
# Positive                           best football play store
# Neutral   perfect app  support arabic language barcode r...
# Negative  not_sense app  total time waste  plz install t...
# Positive                            going stay playing game
# Positive  hello team using call option verification worked
# Positive                            downloaded far love it
# Positive                                          good game
# Positive                        great time waster  fun play
# Positive                                  invaluable asset
# Positive  nice app easy use  great concept  thing like s...
# ...                                                     ...
# Positive                                            useful
# Positive  searching nationwide even though put zip code ...
# Positive  slow update stories specific stocks   explain ...
# Negative  cool need photos videos attached posts  so  ev...
# Negative  payments tend tend generally work  sometimes a...
# Positive                                       wonder woman
# Positive  contains lots ads biggest disadvantage app  ad...
# Positive                           user friendly   love it
# Positive                             not_suitable android
# Positive  love game  hate odus  he s owl  owls fly  fall...
# Positive                                               good
# Positive                 excellent resource diseases drugs
# Negative   like it  not_always lowest prices good interface
# Negative  excellent installing apks wherever storage    ...
# Negative                     dog licking screen gets boring
# Positive  would give   stars constantly sending not_spor...
# Negative  wish got long would lost precious photos more ...
# Negative                                            rubbish
# Positive  unhappy latest update quick edit gone cross co...
# Positive  wonder tool anything thats going person  short...
# Positive  crashes constantly  typing text entry field al...
# Negative  good  adverts not_me; used before  also  think...
# Negative  not_message anyone hit like picture u like bac...
# Positive  come long way  started buggy not_genuinely goo...
# Positive  new update message dear hasbro love game much ...
# Positive  tis bloody awful  s  not_constantly log again ...
# Positive  best coloring app  far  cost extra pictures fa...
# Positive  using several months not_really like simply de...
# Positive  around good app  waiting get interactive train...
# Positive                                    not_informative
#
# [7486 rows x 1 columns]
